# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
data = pd.read_csv('hypertension_dataset.csv')
data
# Out:
#           Country  Age   BMI  Cholesterol  Systolic_BP  Diastolic_BP  \
# 0              UK   58  29.5          230          160            79
# 1           Spain   34  36.2          201          120            84
# 2       Indonesia   73  18.2          173          156            60
# 3          Canada   60  20.3          183          122            94
# 4          France   73  21.8          296           91            97
# ...           ...  ...   ...          ...          ...           ...
# 174977      India   51  39.4          266          174            82
# 174978  Australia   89  39.0          243          104            94
# 174979      India   43  36.5          266          109            98
# 174980    Germany   48  18.3          294          134            84
# 174981  Argentina   27  22.6          205          111            96
#
#        Smoking_Status  Alcohol_Intake Physical_Activity_Level Family_History  \
# ...

# %%
dataclean = data.replace('?', np.nan)
dataclean = data.dropna()
dataclean#already clean
# Out:
#           Country  Age   BMI  Cholesterol  Systolic_BP  Diastolic_BP  \
# 0              UK   58  29.5          230          160            79
# 1           Spain   34  36.2          201          120            84
# 2       Indonesia   73  18.2          173          156            60
# 3          Canada   60  20.3          183          122            94
# 4          France   73  21.8          296           91            97
# ...           ...  ...   ...          ...          ...           ...
# 174977      India   51  39.4          266          174            82
# 174978  Australia   89  39.0          243          104            94
# 174979      India   43  36.5          266          109            98
# 174980    Germany   48  18.3          294          134            84
# 174981  Argentina   27  22.6          205          111            96
#
#        Smoking_Status  Alcohol_Intake Physical_Activity_Level Family_History  \
# ...

# %% [markdown]
# ## Questions to ask
# #### Can we predict whether an individual has hypertension based on their lifestyle, BMI, and cholesterol levels?
# #### Can a model accurately predict heart disease risk using factors like BMI, smoking status, and blood pressure?
# #### What is the relationship between BMI and hypertension across different age groups?

# %%
# Fit the simple linear regression model
